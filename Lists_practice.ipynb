# %% [markdown]
# <a href="https://colab.research.google.com/github/jassu2017/Tdude-ML-2026/blob/main/Lists_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#List is a data type, which is ordered, mutable ,conatins other data types as its element
name = "Hello"
print(name)

fruits = ["apple", "mangoe", "guava"]
print(fruits)
print("First fruit is:",fruits[0])
print("last fruit is:", fruits[-1])
print("adding items to fruit")
fruits.append("grapes")
fruits
fruits.remove("apple")
fruits
# Out:
# Hello
# ['apple', 'mangoe', 'guava']
# First fruit is: apple
# last fruit is: guava
# adding items to fruit
# ['mangoe', 'guava', 'grapes']
